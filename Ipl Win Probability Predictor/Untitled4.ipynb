# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files

# Prompt the user to upload a file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b96aa2eb-371a-4586-a3e7-8c1a5dda3741" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b96aa2eb-371a-4586-a3e7-8c1a5dda3741">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
match = pd.read_csv('matches.csv')
delivery = pd.read_csv('deliveries.csv')

# %%
match.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
match.shape
# Out:
# (756, 18)

# %%
total_score= delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()
# Out:
# <ipython-input-41-08de5e4ed367>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_score= delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
total_score_df = total_score[total_score['inning'] == 1]

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 2            2       1         184
# 4            3       1         183
# 6            4       1         163
# 8            5       1         157
# ...        ...     ...         ...
# 1518     11347       1         143
# 1520     11412       1         136
# 1522     11413       1         171
# 1524     11414       1         155
# 1526     11415       1         152
#
# [756 rows x 3 columns]

# %%
match_df = match.merge(total_score_df[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
teams = [
    'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Royal Challengers Bangalore',
    'Kolkata Knight Riders',
    'Kings XI Punjab',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals'
]

# %%
match_df['team1'] = match_df['team1'].str.replace('Delhi Daredevils','Delhi capitals')
match_df['team2'] = match_df['team2'].str.replace('Delhi Daredevils','Delhi capitals')

match_df['team2'] = match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2'] = match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df.shape
# Out:
# (465, 20)

# %%
match_df = match_df[match_df['dl_applied'] == 0]

# %%
match_df = match_df[['match_id','city','winner','total_runs']]

# %%
delivery_df = match_df.merge(delivery,on='match_id')

# %%
delivery_df = delivery_df[delivery_df['inning'] == 2]

# %%
delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... bye_runs legbye_runs  noball_runs  penalty_runs  \
# 125       CH Gayle  ...        0           0            0             0
# ...

# %%
delivery_df['current_score'] = delivery_df.groupby('match_id').cumsum()['total_runs_y']
# Out:
# <ipython-input-56-cafdf4636499>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   delivery_df['current_score'] = delivery_df.groupby('match_id').cumsum()['total_runs_y']

# %%
delivery_df['runs_lef'] = delivery_df['total_runs_x'] - delivery_df['current_score']

# %%
delivery_df['ball_left'] = 126 - (delivery_df['over']*6 + delivery_df['ball'])

# %%
delivery_df.sample(5)
# Out:
#         match_id        city               winner  total_runs_x  inning  \
# 34514        273      Mumbai       Mumbai Indians           159       2
# 106129     11339   Hyderabad  Sunrisers Hyderabad           232       2
# 31212        235     Chennai  Chennai Super Kings           153       2
# 35740        287  Chandigarh      Kings XI Punjab           163       2
# 11872        110     Chennai     Rajasthan Royals           211       2
#
#                  batting_team         bowling_team  over  ball       batsman  \
# 34514         Kings XI Punjab       Mumbai Indians     2     3   PC Valthaty
# 106129        Kings XI Punjab  Sunrisers Hyderabad     3     4    MA Agarwal
# 31212   Kolkata Knight Riders  Chennai Super Kings     9     3      MS Bisla
# 35740          Mumbai Indians      Kings XI Punjab     2     6  SR Tendulkar
# 11872     Chennai Super Kings     Rajasthan Royals    10     3      PA Patel
#
#         ... penalty_runs batsman_runs  extra_runs  total_runs_y  \
# ...

# %%
# delivery_df.drop(['wickets'],axis=1,inplace=True)

# %%
# delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x: 0 if pd.isna(x) else 1)
# delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')
wickets = delivery_df.groupby('match_id').cumsum()['player_dismissed'].values
delivery_df['wickets'] = 10 - wickets
# delivery_df.head(20)
# Out:
# <ipython-input-62-e33a3b3840b0>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   wickets = delivery_df.groupby('match_id').cumsum()['player_dismissed'].values
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
# 130         1  Hyderabad  Sunrisers Hyderabad           207       2
# 131         1  Hyderabad  Sunrisers Hyderabad           207       2
# 132         1  Hyderabad  Sunrisers Hyderabad           207       2
# ...

# %%
delivery_df.sample(5)
# Out:
#        match_id     city                       winner  total_runs_x  inning  \
# 44966       368  Kolkata          Chennai Super Kings           158       2
# 90940      7934  Kolkata               Mumbai Indians           217       2
# 51514       418  Chennai          Chennai Super Kings           200       2
# 76080       562   Mumbai  Royal Challengers Bangalore           235       2
# 41230       336   Mumbai              Kings XI Punjab           163       2
#
#                 batting_team                 bowling_team  over  ball  \
# 44966    Chennai Super Kings        Kolkata Knight Riders     8     6
# 90940  Kolkata Knight Riders               Mumbai Indians     8     4
# 51514  Kolkata Knight Riders          Chennai Super Kings     8     4
# 76080         Mumbai Indians  Royal Challengers Bangalore    19     3
# 41230        Kings XI Punjab               Mumbai Indians     2     3
#
#            batsman  ... batsman_runs extra_runs  total_runs_y  \
# ...

# %%
#crr = runs/over
delivery_df['crr'] = (delivery_df['current_score']*6) / (120-delivery_df['ball_left'])

# %%
delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... extra_runs total_runs_y  player_dismissed  \
# 125       CH Gayle  ...          0            1                 0
# ...

# %%
delivery_df['rrr'] = (delivery_df['runs_lef']*6)/delivery_df['ball_left']

# %%
def result(row):
  return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result,axis=1)

# %%
delivery_df.columns
# Out:
# Index(['match_id', 'city', 'winner', 'total_runs_x', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'is_super_over', 'wide_runs', 'bye_runs', 'legbye_runs', 'noball_runs',
#        'penalty_runs', 'batsman_runs', 'extra_runs', 'total_runs_y',
#        'player_dismissed', 'dismissal_kind', 'fielder', 'current_score',
#        'runs_lef', 'ball_left', 'wickets', 'crr', 'rrr', 'result'],
#       dtype='object')

# %%
final_df = delivery_df[['batting_team','bowling_team','city','runs_lef','ball_left','wickets','total_runs_x','crr','rrr','result']]

# %%
final_df.head()
# Out:
#                     batting_team         bowling_team       city  runs_lef  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       206
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       206
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       206
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       204
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad       200
#
#      ball_left  wickets  total_runs_x  crr        rrr  result
# 125        119       10           207  6.0  10.386555       0
# 126        118       10           207  3.0  10.474576       0
# 127        117       10           207  2.0  10.564103       0
# 128        116       10           207  4.5  10.551724       0
# 129        115       10           207  8.4  10.434783       0

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample()
# Out:
#                       batting_team     bowling_team        city  runs_lef  \
# 36265  Royal Challengers Bangalore  Kings XI Punjab  Dharamsala       121
#
#        ball_left  wickets  total_runs_x       crr        rrr  result
# 36265         23        1           232  6.865979  31.565217       0

# %%
final_df.isnull().sum()
# Out:
# batting_team      0
# bowling_team      0
# city            589
# runs_lef          0
# ball_left         0
# wickets           0
# total_runs_x      0
# crr               0
# rrr               5
# result            0
# dtype: int64

# %%
final_df.dropna(inplace=True)

# %%
final_df = final_df[final_df['ball_left'] != 0]

# %%
x = final_df.drop(['result'],axis=1)
y = final_df['result']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.2,random_state=61)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,precision_score,accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from  xgboost import XGBClassifier

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[0,1,2])
],remainder='passthrough')
step2 = LogisticRegression(solver='liblinear')

pipe1 = Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe1.fit(xtrain,ytrain)
y_pred = pipe1.predict(xtest)
print('acc scosre',accuracy_score(ytest,y_pred))
print('r2 scosre',r2_score(ytest,y_pred))

print('Precision score',precision_score(ytest,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# acc scosre 0.8079139454475605
# r2 scosre 0.22992229663027763
# Precision score 0.8115863562533838

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[0,1,2])
],remainder='passthrough')
step2 = RandomForestClassifier()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(xtrain,ytrain)
y_pred = pipe.predict(xtest)
print('ac scosre',accuracy_score(ytest,y_pred))
print('r2 scosre',r2_score(ytest,y_pred))

print('Precision score',precision_score(ytest,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ac scosre 0.9993276988090665
# r2 scosre 0.997304728038206
# Precision score 0.9994497432134997

# %%
scores = []
for i in range(100):
  Xtrain,Xtest,Ytrain,Ytest = train_test_split(x,y,test_size=.2,random_state=i)
  pipe1.fit(Xtrain,Ytrain)
  Y_pred = pipe1.predict(Xtest)
  print(scores.append(accuracy_score(Ytest,Y_pred)))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# None
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# None
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# None
# ...

# %%
np.argmax(scores)
# Out:
# 61

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, r2_score, precision_score

# Define the pipeline
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first', handle_unknown='ignore'), [0, 1, 2])
], remainder='passthrough')

step2 = LogisticRegression(solver='liblinear')

pipe3 = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Define the parameter grid for Logistic Regression
param_grid = {
    'step2__C': [0.001, 0.01, 0.1, 1, 10, 100],  # Adjust the values based on your needs
    'step2__penalty': ['l1', 'l2'],
    'step2__fit_intercept': [True, False],
    'step2__intercept_scaling': [1, 2, 3],
    'step2__class_weight': [None, 'balanced'],
    'step2__random_state': [None, 42],
    'step2__max_iter': [50, 100, 200]
}

# Create a GridSearchCV object
grid_search = GridSearchCV(pipe3, param_grid, cv=5, scoring='accuracy')

# Fit the GridSearchCV object to the data
grid_search.fit(xtrain, ytrain)

# Get the best parameters and estimator from the grid search
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

# Print the best parameters
print("Best Parameters:", best_params)

# Use the best estimator to make predictions
y_pred_tuned = best_estimator.predict(xtest)

# Print the performance metrics with the tuned model
print('Accuracy Score:', accuracy_score(ytest, y_pred_tuned))
print('R2 Score:', r2_score(ytest, y_pred_tuned))
print('Precision Score:', precision_score(ytest, y_pred_tuned))
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ...

# %%
final_df.columns
# Out:
# Index(['batting_team', 'bowling_team', 'city', 'runs_lef', 'ball_left',
#        'wickets', 'total_runs_x', 'crr', 'rrr', 'result'],
#       dtype='object')

# %%
def match_progression(x_df,match_id,pipe1):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','city','runs_lef','ball_left','wickets','total_runs_x','crr','rrr']].dropna()
    temp_df = temp_df[temp_df['ball_left'] != 0]
    result = pipe1.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)

    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['runs_lef'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]

    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df,target = match_progression(delivery_df,74,pipe1)
temp_df
# Out:
# Target- 178
#       end_of_over  runs_after_over  wickets_in_over  lose   win
# 6983            1                4                0  51.2  48.8
# 6991            2                8                0  46.0  54.0
# 6997            3                1                0  51.0  49.0
# 7003            4                7                1  64.1  35.9
# 7009            5               12                0  54.0  46.0
# 7015            6               13                0  42.4  57.6
# 7021            7                9                0  36.5  63.5
# 7029            8               15                0  24.3  75.7
# 7035            9                7                0  21.9  78.1
# 7042           10               17                0  12.3  87.7
# 7048           11                9                1  17.8  82.2
# 7054           12                9                0  14.4  85.6
# 7060           13                8                0  12.2  87.8
# ...

# %%
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-178')

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Delhi Capitals']

# %%
delivery_df['city'].unique()
# Out:
# array(['Hyderabad', 'Mumbai', 'Indore', 'Kolkata', 'Bangalore',
#        'Chandigarh', 'Jaipur', 'Chennai', 'Cape Town', 'Port Elizabeth',
#        'Durban', 'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Ahmedabad', 'Nagpur', 'Dharamsala', 'Visakhapatnam', 'Ranchi',
#        'Delhi', 'Abu Dhabi', nan, 'Sharjah', 'Cuttack', 'Pune',
#        'Bengaluru', 'Mohali'], dtype=object)

# %%
import pickle
pickle.dump(pipe1,open('model.pkl','wb'))

# %%
pickle.dump(xtrain,open('data.pkl','wb'))

# %%
xtrain.head()
# Out:
#                 batting_team                 bowling_team        city  \
# 55566        Kings XI Punjab  Royal Challengers Bangalore  Chandigarh
# 44493  Kolkata Knight Riders               Mumbai Indians     Kolkata
# 84600    Chennai Super Kings        Kolkata Knight Riders     Chennai
# 41733         Mumbai Indians              Kings XI Punjab  Chandigarh
# 76314       Rajasthan Royals          Chennai Super Kings     Chennai
#
#        runs_lef  ball_left  wickets  total_runs_x       crr        rrr
# 55566       178        108       10           190  6.000000   9.888889
# 44493        95         45        7           182  6.960000  12.666667
# 84600       122         68        8           207  9.807692  10.764706
# 41733       149        104       10           168  7.125000   8.596154
# 76314        43         19        5           157  6.772277  13.578947

# %%
df.to_pickle('data1.pkl', protocol=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-0817db450119> in <cell line: 1>()
# ----> 1 df.to_pickle('data1.pkl', protocol=4)
#
# NameError: name 'df' is not defined
